# %% [markdown]
# # Linear Regression:
# Linear Regression is a supervised learning algorithm used for predicting a continuous target variable based on one or more input features by modeling the linear relationship between them
# <br>`Equation: y = mx + c`
# <br>
# This is the equation of a straight line — and it's the core idea behind Linear Regression, which is one of the simplest and most widely used algorithms in Machine Learning.
#
# * y	The predicted value (output)
# * x	The input feature (independent variable)
# * m	The slope of the line (also called the weight or coefficient)
# * c	The y-intercept (also called the bias)

# %%
import pandas as pd
data = {
    'area': [750, 800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200],
    'price': [150000, 160000, 170000, 180000, 190000, 200000, 210000, 220000, 230000, 240000]
}

df = pd.DataFrame(data)
print(df)

# ...existing
# Out:
#    area   price
# 0   750  150000
# 1   800  160000
# 2   850  170000
# 3   900  180000
# 4   950  190000
# 5  1000  200000
# 6  1050  210000
# 7  1100  220000
# 8  1150  230000
# 9  1200  240000

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline
plt.scatter(df.area, df.price,color='green', marker='*')
plt.xlabel('Area (sq ft)')  
plt.ylabel('Price ($)')
# Out:
# Text(0, 0.5, 'Price ($)')

# %%
reg_model = LinearRegression()
reg_model.fit(df[['area']], df['price'])
# Out:
# LinearRegression()

# %%
reg_model.predict([[830]])
# Out:
# c:\Users\thahe\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([166000.])
